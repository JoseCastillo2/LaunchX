# %% [markdown]
# # Primer Programa
#
# Mostrar la fecha de hoy.

# %%
from datetime import date
fecha = date.today()
print('La fecha de hoy es: ' + str(fecha))
# Out:
# La fecha de hoy es: 2022-02-10

# %% [markdown]
# Convertidor De Unidades Pársec - Años Luz

# %%
parsec = 11
anioLuz = 3.26156

resultado = anioLuz * parsec

print(str(parsec) + 'parsec = ' + str(resultado) + 'años luz.')
# Out:
# 11parsec = 35.877159999999996años luz.
